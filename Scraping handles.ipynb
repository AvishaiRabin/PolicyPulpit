# %%
html = "https://www.socialseer.com/resources/us-senator-twitter-accounts/"

# %%
from selenium import webdriver
senate = webdriver.Firefox()
senate.get(html)
names = []
senaterange = range(2, 102)
for i in senaterange:
    path = "/html/body/div/div/div/div/article/div/table[1]/tbody/tr[%s]/td[3]/a" % (i)
    element = senate.find_element_by_xpath(path)
    name = element.text
    names.append(name)
# Out:
# SenShelby
# []
# SenDougJones
# ['SenShelby']
# lisamurkowski
# ['SenShelby', 'SenDougJones']
# SenDanSullivan
# ['SenShelby', 'SenDougJones', 'lisamurkowski']
# SenJohnMcCain
# ['SenShelby', 'SenDougJones', 'lisamurkowski', 'SenDanSullivan']
# JeffFlake
# ['SenShelby', 'SenDougJones', 'lisamurkowski', 'SenDanSullivan', 'SenJohnMcCain']
# SenTomCotton
# ['SenShelby', 'SenDougJones', 'lisamurkowski', 'SenDanSullivan', 'SenJohnMcCain', 'JeffFlake']
# JohnBoozman
# ['SenShelby', 'SenDougJones', 'lisamurkowski', 'SenDanSullivan', 'SenJohnMcCain', 'JeffFlake', 'SenTomCotton']
# SenFeinstein
# ['SenShelby', 'SenDougJones', 'lisamurkowski', 'SenDanSullivan', 'SenJohnMcCain', 'JeffFlake', 'SenTomCotton', 'JohnBoozman']
# SenKamalaHarris
# ['SenShelby', 'SenDougJones', 'lisamurkowski', 'SenDanSullivan', 'SenJohnMcCain', 'JeffFlake', 'SenTomCotton', 'JohnBoozman', 'SenFeinstein']
# SenBennetCO
# ...

# %%
for name in names:
    print(name)
# Out:
# ['SenShelby', 'SenDougJones', 'lisamurkowski', 'SenDanSullivan', 'SenJohnMcCain', 'JeffFlake', 'SenTomCotton', 'JohnBoozman', 'SenFeinstein', 'SenKamalaHarris', 'SenBennetCO', 'SenCoryGardner', 'ChrisMurphyCT', 'SenBlumenthal', 'SenatorCarper', 'ChrisCoons', 'SenBillNelson', 'marcorubio', 'SenDavidPerdue', 'SenatorIsakson', 'brianschatz', 'maziehirono', 'MikeCrapo', 'SenatorRisch', 'SenDuckworth', 'SenatorDurbin', 'SenDonnelly', 'SenToddYoung', 'ChuckGrassley', 'joniernst', 'SenPatRoberts', 'JerryMoran', 'SenateMajLdr', 'RandPaul', 'BillCassidy', 'SenJohnKennedy', 'SenAngusKing', 'SenatorCollins', 'ChrisVanHollen', 'SenatorCardin', 'senmarkey', 'SenWarren', 'SenGaryPeters', 'SenStabenow', 'amyklobuchar', 'SenTinaSmith', 'SenThadCochran', 'SenatorWicker', 'clairecmc', 'RoyBlunt', 'SteveDaines', 'SenatorTester', 'SenatorFischer', 'BenSasse', 'SenCortezMasto', 'SenDeanHeller', 'SenatorShaheen', 'SenatorHassan', 'CoryBooker', 'SenatorMenendez', 'MartinHeinrich', 'SenatorTomUdall', 'SenSc
# ...

# %%
from selenium import webdriver
senate = webdriver.Firefox()
senate.get(html)
path = "/html/body/div/div/div/div/article/div/table[1]/tbody/tr[6]/td[2]"
element = senate.find_element_by_xpath(path)

# %%
element.text
# Out:
# 'McCain, John'
